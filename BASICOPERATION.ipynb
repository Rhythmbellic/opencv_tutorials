# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
print(cv2.__version__)
# Out:
# 4.8.0

# %%
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# !unzip -qq images.zip
# Out:
# --2023-09-03 19:32:01--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 3.5.246.13, 52.95.191.10, 3.5.244.113, ...
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|3.5.246.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29586716 (28M) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  28.22M  4.55MB/s    in 11s
#
# 2023-09-03 19:32:13 (2.48 MB/s) - ‘images.zip’ saved [29586716/29586716]

# %%
image=cv2.imread('/content/images/castara.jpeg')

# %%
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(image)
plt.show()

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
imshow("Displaying our first image",image)

# %%
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
image.shape
# Out:
# (1280, 960, 3)

# %%
print(image.shape[0])
print(image.shape[1])
image.shape[2]
# Out:
# 1280
# 960
# 3

# %%
# Out:
# Height of Image: 1280 pixels
# Width of Image: 960 pixels
# Depth of Image: 3 colors components

# %%
print(f'height of the image is { image.shape[0]}')
print(f'widtht of the image is { image.shape[1]}')
print(f'numbers of the channelt of the image is { image.shape[2]}')
# Out:
# height of the image is 1280
# widtht of the image is 960
# numbers of the channelt of the image is 3
