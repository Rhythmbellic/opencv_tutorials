# %% [markdown]
# <a href="https://colab.research.google.com/github/Rhythmbellic/opencv_tutorials/blob/main/arithmetic_and_bitwise_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# !unzip --q images.zip
def imshow(title="",image=None,size=10):
  w,h=image.shape[1],image.shape[0]
  aspect_ratio=w/h
  plt.figure(figsize=(size*aspect_ratio,size))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()
# Out:
# --2023-09-02 16:46:42--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 52.95.148.66, 52.95.191.22, 52.95.191.70, ...
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|52.95.148.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29586716 (28M) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  28.22M  8.27MB/s    in 3.4s
#
# 2023-09-02 16:46:46 (8.27 MB/s) - ‘images.zip’ saved [29586716/29586716]
#
# Archive:  images.zip
#    creating: images/
#   inflating: images/castara.jpeg
#   inflating: __MACOSX/images/._castara.jpeg
#   inflating: images/londonxmas2.jpeg
#   inflating: __MACOSX/images/._londonxmas2.jpeg
#   inflating: images/coffee_view.jpeg
#   inflating: __MACOSX/images/._coffee_view.jpeg
# ...

# %%
image=cv2.imread('/content/images/londonxmas.jpeg',0)
imshow('orignal',image)

# %%
r=np.ones(image.shape,dtype='uint8')*100

# %%
r
# Out:
# array([[100, 100, 100, ..., 100, 100, 100],
#        [100, 100, 100, ..., 100, 100, 100],
#        [100, 100, 100, ..., 100, 100, 100],
#        ...,
#        [100, 100, 100, ..., 100, 100, 100],
#        [100, 100, 100, ..., 100, 100, 100],
#        [100, 100, 100, ..., 100, 100, 100]], dtype=uint8)

# %%
image
# Out:
# array([[ 4,  4,  4, ...,  3,  3,  3],
#        [ 4,  4,  4, ...,  3,  3,  3],
#        [ 4,  4,  4, ...,  3,  3,  3],
#        ...,
#        [20, 20, 21, ..., 12, 12, 12],
#        [23, 23, 24, ..., 12, 11, 11],
#        [25, 25, 26, ..., 12, 11, 11]], dtype=uint8)

# %%
imshow('whitened image',r)

# %%
add=cv2.add(image,r)

# %%
imshow('brithened image',add)

# %%
add2=cv2.add(add,r)

# %%
imshow("more brithened",add2)

# %%
substracted=cv2.subtract(image,r)
imshow('subracted image',substracted)

# %%
substraction2=image-r
imshow('subtracted',substraction2)

# %% [markdown]
# ##bitwise operator

# %%
square=np.zeros((300,300),np.uint8)
cv2.rectangle(square,(50,50),(250,250),255,-2)
imshow('blank',square)

# %%
ellipse=np.zeros((300,300),np.uint8)
cv2.ellipse(ellipse,(150,150),(150,150),30,0,180,255,-1)
imshow('blank',ellipse)

# %%
from numpy.ma.core import bitwise_and
And=cv2.bitwise_and(square,ellipse)
Or=cv2.bitwise_or(square,ellipse)
Xor=cv2.bitwise_xor(square,ellipse)
Not=cv2.bitwise_not(square,ellipse)

# %%
imshow('and',And)
imshow('or',Or)
imshow('xor',Xor)
imshow('not',Not)
